# %% [markdown]
# <a href="https://colab.research.google.com/github/imreverse/OhhYeahhhhhhSpreadIT/blob/main/DeadEnd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/AlexeyAB/darknet
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !/usr/local/cuda/bin/nvcc --version
# !make
#!wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# fatal: destination path 'darknet' already exists and is not an empty directory.
# /content/darknet
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ...

# %%
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()


#!./darknet detect cfg/yolov3.cfg yolov3.weights data/person.jpg
#imShow('predictions.jpg')

# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')

# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# /content
# Mounted at /content/gdrive
# 'Colab Notebooks'		      obj_test.zip
#  Dhokla.zip			     'proj-report (1)-converted.gdoc'
# 'Dosa And Naan (Large Dataset).zip'  'SYNOPSIS - II.gdoc'
#  Khandvi.zip			      yolov3
# 'Labeled Images(Small Dataset).zip'   yolov3_2

# %%
# %cd darknet
# Out:
# /content/darknet

# %%
# !ls /mydrive/yolov3_2
# !cp /mydrive/yolov3_2/obj.zip ../
# !unzip ../obj.zip -d data/
# Out:
# backup		  generate_train.py  obj.names	   obj.zip
# generate_test.py  obj.data	     obj_test.zip  yolov3_custom.cfg
# Archive:  ../obj.zip
#    creating: data/obj/
#   inflating: data/obj/jalebi94.jpg
#   inflating: data/obj/dhokla107.txt
#   inflating: data/obj/jalebi21.jpg
#   inflating: data/obj/00000003 (3).txt
#   inflating: data/obj/idlytrain (18).txt
#   inflating: data/obj/butternaantrain (21).txt
#   inflating: data/obj/samosatrain (68).jpg
#   inflating: data/obj/butternaantrain (17).jpg
#   inflating: data/obj/butternaantrain (57).txt
#   inflating: data/obj/jalebi48.txt
#   inflating: data/obj/butternaantrain (52).txt
#   inflating: data/obj/samosatrain (30).jpg
#   inflating: data/obj/samosatrain (36).jpg
#   inflating: data/obj/butternaantrain (19).jpg
#   inflating: data/obj/dosatrain (31).txt
#   inflating: data/obj/00000017 (1).jpg
#   inflating: data/obj/khandvi129.jpg
#   inflating: data/obj/gappe1.txt
#   inflating: data/obj/idlytrain (59).jpg
# ...

# %%
# !cp /mydrive/yolov3_2/yolov3_custom.cfg ./cfg

# %%
# !cp /mydrive/yolov3_2/obj.names ./data
# !cp /mydrive/yolov3_2/obj.data  ./data

# %%
# !cp /mydrive/yolov3_2/generate_train.py ./
# !python generate_train.py
# !ls data/
# Out:
# 9k.tree     eagle.jpg	 imagenet.labels.list	   obj.data	     scream.jpg
# coco9k.map  giraffe.jpg  imagenet.shortnames.list  obj.names	     train.txt
# coco.names  goal.txt	 labels			   openimages.names  voc.names
# dog.jpg     horses.jpg	 obj			   person.jpg

# %%
# !wget http://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-02-27 10:40:12--  http://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://pjreddie.com/media/files/darknet53.conv.74 [following]
# --2021-02-27 10:40:12--  https://pjreddie.com/media/files/darknet53.conv.74
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  75.0MB/s    in 2.1s
#
# 2021-02-27 10:40:14 (75.0 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !ls
# Out:
# 3rdparty	darknet			image_yolov3.sh        obj
# backup		darknet53.conv.74	image_yolov4.sh        README.md
# build		DarknetConfig.cmake.in	include		       results
# build.ps1	darknet_images.py	json_mjpeg_streams.sh  scripts
# build.sh	darknet.py		LICENSE		       src
# cfg		darknet_video.py	Makefile	       vcpkg.json
# cmake		data			net_cam_v3.sh	       video_yolov3.sh
# CMakeLists.txt	generate_train.py	net_cam_v4.sh	       video_yolov4.sh

# %%
## Training
# !./darknet detector train data/obj.data cfg/yolov3_custom.cfg darknet53.conv.74 -dont_show
# Out:
#  CUDA-version: 10010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# yolov3_custom
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 4, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
imShow('chart.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-096d9cb64b19> in <module>()
# ----> 1 imShow('chart.png')
#
# <ipython-input-2-5e6e7e5b588e> in imShow(path)
#       5
#       6   image = cv2.imread(path)
# ----> 7   height, width = image.shape[:2]
#       8   resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)
#       9
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
# !./darknet detector train data/obj.data cfg/yolov3_custom.cfg /mydrive/yolov3_2/backup/yolov3_custom_last.weights -dont_show
# Out:
#  CUDA-version: 10010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# yolov3_custom
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 4, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
# !ls /mydrive/yolov3_2
# !cp /mydrive/yolov3_2/obj_test.zip ../
# !unzip ../obj_test.zip -d data/
# Out:
# backup		  generate_train.py  obj.names	   obj.zip
# generate_test.py  obj.data	     obj_test.zip  yolov3_custom.cfg
# Archive:  ../obj_test.zip
#    creating: data/obj_test/
#   inflating: data/obj_test/khandvi184.txt
#   inflating: data/obj_test/vadapavtest (3).jpg
#   inflating: data/obj_test/gulab133.jpg
#   inflating: data/obj_test/dhokla205.txt
#   inflating: data/obj_test/idlytest (28).txt
#   inflating: data/obj_test/gappe106.txt
#   inflating: data/obj_test/dosatest (1).txt
#   inflating: data/obj_test/naantest (24).jpg
#   inflating: data/obj_test/gulab140.jpg
#   inflating: data/obj_test/naantest (3).jpg
#   inflating: data/obj_test/jalebi141.txt
#   inflating: data/obj_test/samosatest (4).jpg
#   inflating: data/obj_test/khandvi192.jpg
#   inflating: data/obj_test/gulab148.jpg
#   inflating: data/obj_test/naantest (27).jpg
#   inflating: data/obj_test/gulab150.txt
#   inflating: data/obj_test/vadapavtest (12).txt
#   inflating: data/obj_test/idlytest (2).jpg
# ...

# %%
# !cp /mydrive/yolov3_2/generate_test.py ./
# !python generate_test.py
# !ls data/
# Out:
# 9k.tree     giraffe.jpg		      labels	 openimages.names  voc.names
# coco9k.map  goal.txt		      obj	 person.jpg
# coco.names  horses.jpg		      obj.data	 scream.jpg
# dog.jpg     imagenet.labels.list      obj.names  test.txt
# eagle.jpg   imagenet.shortnames.list  obj_test	 train.txt

# %%
# !./darknet detector test data/obj.data /mydrive/yolov3_2/yolov3_custom2.cfg /mydrive/yolov3_2/backup/yolov3_custom_last.weights
# Out:
# ^C

# %%
# !./darknet detector map data/obj.data /mydrive/yolov3_2/yolov3_custom2.cfg /mydrive/yolov3_2/backup/yolov3_custom_last.weights -dont_show -ext_output < data/test.txt > result.txt
# Out:
#  CUDA-version: 10010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
# ...
